# %% [markdown]
# # 03｜组件对比实验
#
# 每次只替换一个组件，其余条件保持一致。每一列对应一种设置，
# 从上到下依次查看决策边界、Loss、Accuracy 和梯度。

# %%
# %matplotlib inline
from pathlib import Path
import sys

LAB_DIR = Path.cwd()
if not (LAB_DIR / "mlp_lab").is_dir():
    LAB_DIR = (Path.cwd() / "01_mlp_lab").resolve()
if str(LAB_DIR) not in sys.path:
    sys.path.insert(0, str(LAB_DIR))

from mlp_lab import compare

# %% [markdown]
# ## 对比激活函数

# %%
activation_results = compare(
    "activation", dataset="moons", device="auto", epochs=35, n_samples=360
)
# Out:
# 配置对比
# --------------------------------------------------------------------------------------
# 配置                                   测试准确率         参数量       耗时(秒)          末轮梯度
# --------------------------------------------------------------------------------------
# 激活函数：relu                           93.3%       1,218        0.41         0.237
# 激活函数：tanh                           93.3%       1,218        0.25        0.2454
# 激活函数：sigmoid                        91.1%       1,218        0.25        0.1098
# --------------------------------------------------------------------------------------

# %% [markdown]
# ## 对比优化器

# %%
optimizer_results = compare(
    "optimizer", dataset="moons", device="auto", epochs=35, n_samples=360
)
# Out:
# 配置对比
# --------------------------------------------------------------------------------------
# 配置                                   测试准确率         参数量       耗时(秒)          末轮梯度
# --------------------------------------------------------------------------------------
# 优化器：sgd                             84.4%       1,218        0.23        0.2233
# 优化器：momentum                        91.1%       1,218        0.22        0.2094
# 优化器：adam                            93.3%       1,218        0.24         0.237
# --------------------------------------------------------------------------------------

# %% [markdown]
# **记录要求：**不要只写“哪个准确率最高”。还要指出边界形状、收敛速度、
# 训练/测试差距，以及结论所依赖的数据与训练轮数。
